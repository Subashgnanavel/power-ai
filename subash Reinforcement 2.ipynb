# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/content/housing.csv')
data
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02/05/2014 0:00  3.130000e+05         3       1.50       1340.0
# 1     02/05/2014 0:00  2.384000e+06         5       2.50       3650.0
# 2     02/05/2014 0:00  3.420000e+05         3       2.00       1930.0
# 3     02/05/2014 0:00  4.200000e+05         3       2.25       2000.0
# 4     02/05/2014 0:00  5.500000e+05         4       2.50       1940.0
# ...               ...           ...       ...        ...          ...
# 4595  09/07/2014 0:00  3.081667e+05         3       1.75       1510.0
# 4596  09/07/2014 0:00  5.343333e+05         3       2.50       1460.0
# 4597  09/07/2014 0:00  4.169042e+05         3       2.50       3010.0
# 4598  10/07/2014 0:00  2.034000e+05         4       2.00       2090.0
# 4599  10/07/2014 0:00  2.206000e+05         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
data.isnull().sum()
# Out:
# date               0
# price              0
# bedrooms           0
# bathrooms          0
# sqft_living       40
# sqft_lot          14
# floors             0
# waterfront         0
# view               0
# condition          0
# sqft_above         0
# sqft_basement      0
# yr_built          23
# yr_renovated       0
# street             0
# city              57
# statezip           0
# country            0
# House_Age         23
# price_per_sqft    40
# dtype: int64

# %%
print(data.head(6))
print(data.info())
# Out:
#               date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02/05/2014 0:00   313000.0         3       1.50       1340.0       NaN
# 1  02/05/2014 0:00  2384000.0         5       2.50       3650.0       NaN
# 2  02/05/2014 0:00   342000.0         3       2.00       1930.0       NaN
# 3  02/05/2014 0:00   420000.0         3       2.25       2000.0       NaN
# 4  02/05/2014 0:00   550000.0         4       2.50       1940.0       NaN
# 5  02/05/2014 0:00   490000.0         2       1.00        880.0       NaN
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0    1955.0
# 1     2.0           0     4          5        3370            280    1921.0
# 2     1.0           0     0          4        1930              0    1966.0
# 3     1.0           0     0          4        1000           1000    1963.0
# ...

# %%
data.drop(["Street", "Statezip", "Country"], axis=1, inplace=True, errors="ignore")
data
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02/05/2014 0:00  3.130000e+05         3       1.50       1340.0
# 1     02/05/2014 0:00  2.384000e+06         5       2.50       3650.0
# 2     02/05/2014 0:00  3.420000e+05         3       2.00       1930.0
# 3     02/05/2014 0:00  4.200000e+05         3       2.25       2000.0
# 4     02/05/2014 0:00  5.500000e+05         4       2.50       1940.0
# ...               ...           ...       ...        ...          ...
# 4595  09/07/2014 0:00  3.081667e+05         3       1.75       1510.0
# 4596  09/07/2014 0:00  5.343333e+05         3       2.50       1460.0
# 4597  09/07/2014 0:00  4.169042e+05         3       2.50       3010.0
# 4598  10/07/2014 0:00  2.034000e+05         4       2.00       2090.0
# 4599  10/07/2014 0:00  2.206000e+05         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
data["House_Age"] = 2025 - data["yr_built"]
data
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02/05/2014 0:00  3.130000e+05         3       1.50       1340.0
# 1     02/05/2014 0:00  2.384000e+06         5       2.50       3650.0
# 2     02/05/2014 0:00  3.420000e+05         3       2.00       1930.0
# 3     02/05/2014 0:00  4.200000e+05         3       2.25       2000.0
# 4     02/05/2014 0:00  5.500000e+05         4       2.50       1940.0
# ...               ...           ...       ...        ...          ...
# 4595  09/07/2014 0:00  3.081667e+05         3       1.75       1510.0
# 4596  09/07/2014 0:00  5.343333e+05         3       2.50       1460.0
# 4597  09/07/2014 0:00  4.169042e+05         3       2.50       3010.0
# 4598  10/07/2014 0:00  2.034000e+05         4       2.00       2090.0
# 4599  10/07/2014 0:00  2.206000e+05         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
data["price_per_sqft"] = data["price"] / data["sqft_living"]
data
# Out:
#                  date         price  bedrooms  bathrooms  sqft_living  \
# 0     02/05/2014 0:00  3.130000e+05         3       1.50       1340.0
# 1     02/05/2014 0:00  2.384000e+06         5       2.50       3650.0
# 2     02/05/2014 0:00  3.420000e+05         3       2.00       1930.0
# 3     02/05/2014 0:00  4.200000e+05         3       2.25       2000.0
# 4     02/05/2014 0:00  5.500000e+05         4       2.50       1940.0
# ...               ...           ...       ...        ...          ...
# 4595  09/07/2014 0:00  3.081667e+05         3       1.75       1510.0
# 4596  09/07/2014 0:00  5.343333e+05         3       2.50       1460.0
# 4597  09/07/2014 0:00  4.169042e+05         3       2.50       3010.0
# 4598  10/07/2014 0:00  2.034000e+05         4       2.00       2090.0
# 4599  10/07/2014 0:00  2.206000e+05         3       2.50       1490.0
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(5,5))
sns.histplot(data["price"], kde=True)
plt.title("Distribution of House Prices")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x="bedrooms", data=data)
plt.title("Count of bedrooms")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=data["bathrooms"])
plt.title("Boxplot of bathrooms")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x="sqft_living", y="price", data=data)
plt.title("Sqft_living vs Price")
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x="waterfront", y="price", data=data)
plt.title("Waterfront vs Price")
plt.show()

# %%
plt.figure(figsize=(5,5))
corr = data[["bedrooms","bathrooms","sqft_living","floors","price"]].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
avg_price_city = data.groupby("city")["price"].mean().sort_values(ascending=False)
print("\nAverage House Price by City:")
print(avg_price_city)
# Out:
# Average House Price by City:
# city
# Medina                 2.046559e+06
# Clyde Hill             1.321945e+06
# Yarrow Point           1.194838e+06
# Mercer Island          1.123818e+06
# Bellevue               8.516243e+05
# Beaux Arts Village     7.450000e+05
# Fall City              7.284500e+05
# Sammamish              6.882779e+05
# Redmond                6.669215e+05
# Newcastle              6.660467e+05
# Kirkland               6.527872e+05
# Woodinville            6.131418e+05
# North Bend             5.998082e+05
# Issaquah               5.975969e+05
# Seattle                5.793213e+05
# Preston                5.624500e+05
# Snoqualmie             5.324301e+05
# Snoqualmie Pass        5.250000e+05
# Carnation              5.194544e+05
# Ravensdale             5.140714e+05
# Normandy Park          5.128985e+05
# Bothell                4.775833e+05
# Vashon                 4.725569e+05
# Lake Forest Park       4.480600e+05
# Kenmore                4.474940e+05
# ...

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x="sqft_living", y="price", data=data, palette="Set1")
plt.title("Sqft_living vs Price with points coloured by condition ")
plt.show()
# Out:
# /tmp/ipython-input-834728870.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x="sqft_living", y="price", data=data, palette="Set1")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,r2_score

# %%
x = data[["sqft_living"]]
y = data["price"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
plt.figure(figsize=(5,5))
plt.scatter(x_train, y_train, color='yellow', label='Training Data')
plt.scatter(x_test, y_test, color='red', label='Testing Data')
